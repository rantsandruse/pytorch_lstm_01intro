# %%
# If your working dir is pytorch_lstm_01intro, you need to move up one level to use the library. 
import os
cwd = os.getcwd() 
pwd = cwd.replace("pytorch_lstm_01intro/", "")
os.chdir(pwd)

print(pwd)
# Out:
# /home/sishi/NLP/pytorch_in_ten_days

# %%
'''
This is essentially the same as main_v2.ipynb 
The main improvements are:
1. Now the input is a customizable csv, instead of hard coded in the text
2. Build a customizable training function.
'''
import torch
import torch.nn as nn

import torch.optim as optim
import pandas as pd

from pytorch_lstm_01intro.model_lstm_tagger import LSTMTagger
from pytorch_lstm_01intro.preprocess import seq_to_embedding, seqs_to_dictionary
from pytorch_lstm_01intro.train import train, test

# %%
torch.manual_seed(1)
EMBEDDING_DIM = 6
HIDDEN_DIM = 6

# read in raw data
training_data_raw = pd.read_csv("./pytorch_lstm_01intro/train.csv")
# create mappings

#split texts and tags into training data.
texts = [t.split() for t in training_data_raw["text"].tolist()]
tags_list = [t.split() for t in training_data_raw["tag"].tolist()]

training_data = list(zip(texts, tags_list))

# %%
# Create mapping 
word_to_ix, tag_to_ix = seqs_to_dictionary(training_data)

print(word_to_ix)
print(tag_to_ix)
# Out:
# {'The': 0, 'dog': 1, 'ate': 2, 'the': 3, 'apple': 4, 'Everybody': 5, 'read': 6, 'book': 7}
# {'DET': 0, 'NN': 1, 'V': 2}

# %%
# Usually 32 or 64 dim. Keeping them small
# You can toggle is_nll_loss on or off. 

model = LSTMTagger(EMBEDDING_DIM, HIDDEN_DIM, len(
    word_to_ix), len(tag_to_ix), is_nll_loss=True)

loss_function = nn.NLLLoss() if model.is_nll_loss else nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.1)

# %%
# get embeddings
# See what the scores are before training
# Note that element i,j of the output is the score for tag j for word i.
# Here we don't need to train, so the code is wrapped in torch.no_grad()
testing_data = "The dog ate the book"

print("tag_scores before training:")
test(testing_data, model, word_to_ix)

train(model, loss_function, training_data, word_to_ix, tag_to_ix, optimizer, epoch=100)
# Out:
# tag_scores before training:
# Using NLL Loss:
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  0 : tensor(1.1028, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  0 : tensor(1.2176, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  1 : tensor(1.0891, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  1 : tensor(1.1964, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  2 : tensor(1.0771, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  2 : tensor(1.1775, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  3 : tensor(1.0666, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  3 : tensor(1.1607, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  4 : tensor(1.0574, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  4 : tensor(1.1456, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  5 : tensor(1.0493, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  5 : tensor(1.1320, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  6 : tensor(1.0422, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  6 : tensor(1.1199, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  7 : tensor(1.0359, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  7 : tensor(1.1091, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  8 : tensor(1.0304, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  8 : tensor(1.0993, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  9 : tensor(1.0255, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  9 : tensor(1.0905, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  10 : tensor(1.0211, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  10 : tensor(1.0825, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  11 : tensor(1.0171, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  11 : tensor(1.0752, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  12 : tensor(1.0135, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  12 : tensor(1.0686, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  13 : tensor(1.0102, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  13 : tensor(1.0626, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch
grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  63 : tensor(0.8282, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  63 : tensor(0.8628, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  64 : tensor(0.8225, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  64 : tensor(0.8569, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  65 : tensor(0.8167, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  65 : tensor(0.8509, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  66 : tensor(0.8108, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  66 : tensor(0.8447, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  67 : tensor(0.8048, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  67 : tensor(0.8384, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  68 : tensor(0.7987, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  68 : tensor(0.8319, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  69 : tensor(0.7925, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  69 : tensor(0.8253, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  70 : tensor(0.7863, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  70 : tensor(0.8186, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  71 : tensor(0.7799, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  71 : tensor(0.8118, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  72 : tensor(0.7735, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  72 : tensor(0.8048, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  73 : tensor(0.7671, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  73 : tensor(0.7978, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  74 : tensor(0.7605, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  74 : tensor(0.7905, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  75 : tensor(0.7539, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  75 : tensor(0.7832, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  76 : tensor(0.7472, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  76 : tensor(0.7758, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  77 : tensor(0.7405, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  77 : tensor(0.7682, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  78 : tensor(0.7337, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  78 : tensor(0.7605, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  79 : tensor(0.7268, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  79 : tensor(0.7527, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  80 : tensor(0.7199, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  80 : tensor(0.7449, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  81 : tensor(0.7130, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  81 : tensor(0.7369, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  82 : tensor(0.7060, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  82 : tensor(0.7288, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  83 : tensor(0.6989, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  83 : tensor(0.7206, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  84 : tensor(0.6919, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  84 : tensor(0.7124, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  85 : tensor(0.6848, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  85 : tensor(0.7041, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  86 : tensor(0.6776, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  86 : tensor(0.6957, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  87 : tensor(0.6705, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  87 : tensor(0.6872, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  88 : tensor(0.6633, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  88 : tensor(0.6786, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  89 : tensor(0.6562, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  89 : tensor(0.6700, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  90 : tensor(0.6490, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  90 : tensor(0.6614, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  91 : tensor(0.6418, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  91 : tensor(0.6527, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  92 : tensor(0.6346, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  92 : tensor(0.6439, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  93 : tensor(0.6274, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  93 : tensor(0.6351, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  94 : tensor(0.6201, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  94 : tensor(0.6262, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  95 : tensor(0.6129, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  95 : tensor(0.6173, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  96 : tensor(0.6057, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  96 : tensor(0.6084, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  97 : tensor(0.5986, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  97 : tensor(0.5994, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  98 : tensor(0.5914, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  98 : tensor(0.5904, grad_fn=<NllLossBackward>)
# ['The', 'dog', 'ate', 'the', 'apple']
# ['DET', 'NN', 'V', 'DET', 'NN']
# loss for epoch  99 : tensor(0.5842, grad_fn=<NllLossBackward>)
# ['Everybody', 'read', 'the', 'book']
# ['NN', 'V', 'DET', 'NN']
# loss for epoch  99 : tensor(0.5813, grad_fn=<NllLossBackward>)

# %%
# We roughly expect 0, 1, 2, 0, 1 
print("tag_scores after training:")
test(testing_data, model, word_to_ix)
# Out:
# tag_scores after training:
# Using NLL Loss:
# tensor([[0.6192, 0.2967, 0.0841],
#         [0.2137, 0.6324, 0.1538],
#         [0.0739, 0.4424, 0.4837],
#         [0.5729, 0.3131, 0.1140],
#         [0.1383, 0.6766, 0.1851]])
